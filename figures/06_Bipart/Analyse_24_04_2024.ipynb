# %%
import numpy as np
import scipy as sp

import scipy
print(scipy.__version__)


date = '2024-04-24'
scans = np.array([62 ])
#scans = np.array([89])
scan=scans[0]

fichier = f"/media/pucemanip/manip/data/{date}/scan{str(scan).zfill(3)}/scan{str(scan).zfill(3)}data001.mat"
#fichier = f"/home/isabellebouchoule/Puce/analysedata/{date}/scan{str(scan).zfill(3)}/scan{str(scan).zfill(3)}data001.mat"
lesparams = sp.io.loadmat(fichier)['gusparam'][0]
print(sorted([lesparams[2*i][0] for i in range(int(len(lesparams)/2))]))
param_names = ['X1_bis' ]  # List of parameter names
for param in param_names :
    if  param not in lesparams : print( f"{param} not in lesparams" )

# %run Import_donnees_n_parametres.ipynb
# Out:
# 1.14.1
# [np.str_('ACAmplitudeRFdebut'), np.str_('ACDCBxfive'), np.str_('ACDCByfive'), np.str_('ACDCZbiasthree'), np.str_('AmpitudeRFfinexp'), np.str_('AmplitudeRFfinal'), np.str_('AmplitudeRFinit'), np.str_('BUMotz'), np.str_('BiasUmot'), np.str_('BxImg'), np.str_('BxMOT'), np.str_('BxMolasses'), np.str_('Bxdisp'), np.str_('Bxpumping'), np.str_('ByACtrap'), np.str_('ByMOT'), np.str_('ByMolasses'), np.str_('Bydisp'), np.str_('Bypumping'), np.str_('BzImg'), np.str_('BzMOT'), np.str_('BzMolasses'), np.str_('BzZtrap'), np.str_('Bzdisp'), np.str_('Bzpumping'), np.str_('DcourantAC'), np.str_('DcurrentACDC1'), np.str_('DcurrentACDC2'), np.str_('DcurrentACDC3'), np.str_('DcurrentEnd'), np.str_('DeadtimeDMD'), np.str_('DeadtimeDMD_bis'), np.str_('DelaichampZtrap'), np.str_('DelayTriger'), np.str_('Device_angle'), np.str_('Device_angle_1'), np.str_('DprimeACDC1'), np.str_('DprimeACDC2'), np.str_('DprimecourantAC'), np.str_('EndRotationtime'), np.str_('FreqCompress'), np.str_('FreqIni'), np.str_('GradBz'), np.str_('GradBzexp'), np.str_('Height'), np.str_('IDprharmonic'), np.str_('IDprquartic'), np.str_('IDquartic'), np.str_('Ismalldprquartic'), np.str_('Ismalldquartic'), np.str_('IzAC'), np.str_('IzAC0'), np.str_('IzoffDCfour'), np.str_('IzoffDCone'), np.str_('IzoffDCthree'), np.str_('IzoffDCtwo'), np.str_('Pumpdetuning'), np.str_('QuarticTime'), np.str_('QuarticWaitTime'), np.str_('RFIzAC'), np.str_('RFfreACfinal'), np.str_('RFfreqACdebut'), np.str_('RFfreqACdebutexp'), np.str_('RFfreqACfin'), np.str_('RFfreqACfinexp'), np.str_('RFfreqACshield'), np.str_('RFfreqshield'), np.str_('RFshieldramptime'), np.str_('RFshieldtime'), np.str_('Rotationtime'), np.str_('TAC'), np.str_('TACtrapRFexp'), np.str_('TCoupureRFAC'), np.str_('T_PMO'), np.str_('Tbreathing'), np.str_('TcoupureD'), np.str_('TdynoffDC'), np.str_('Tempsvolmelasse'), np.str_('Texpansion'), np.str_('TimeOscParam'), np.str_('TimeoffDC'), np.str_('TimeoffDCfive'), np.str_('TimeoffDCthree'), np.str_('TimeoffDCtwo'), np.str_('TpulseDMD'), np.str_('Transferttime'), np.str_('TransportDcurrent'), np.str_('TransportDprimecurrent'), np.str_('TtransfertAC'), np.str_('Tvlongcoupure'), np.str_('UMOTdetuning'), np.str_('Ufinalcurrent'), np.str_('Ufinaldetuning'), np.str_('Uloadcurrent'), np.str_('Utransfertime'), np.str_('Width'), np.str_('Width1'), np.str_('X0'), np.str_('X1'), np.str_('X1_bis'), np.str_('Y0'), np.str_('Y1'), np.str_('Zangle'), np.str_('Zbias'), np.str_('Zcompresstime'), np.str_('ZcompresstimeB'), np.str_('Zcurrent'), np.str_('Zfreq1'), np.str_('Zloadcurrent'), np.str_('Zloadtime'), np.str_('ZrampcourantACDC'), np.str_('Zrffinal'), np.str_('alphaI'), np.str_('alphax'), np.str_('alphay'), np.str_('angleUmot'), np.str_('config_DMD_bis'), np.str_('currentZpulse'), np.str_('deadtime'), np.str_('delta'), np.str_('detuning'), np.str_('detuningDMD'), np.str_('detuningImg'), np.str_('dummy'), np.str_('molassesdetuning'), np.str_('molassesintensity'), np.str_('molassestime'), np.str_('poscam'), np.str_('pulselength'), np.str_('pulselengthpump'), np.str_('ramptime'), np.str_('tauACtrapRF'), np.str_('tauRF_Z'), np.str_('timeOsc'), np.str_('timeflight'), np.str_('ucompresstime'), np.str_('ufinalangle'), np.str_('ufinalbias'), np.str_('umottime'), np.str_('xACDC'), np.str_('zloadangle'), np.str_('zloadbias'), np.str_('zrftime')]
# Version de Python: 3.10.12
#
# Isat= 16.635141621871774
#
#  ['scan062data001.mat', 'scan062data002.mat', 'scan062data003.mat', 'scan062data004.mat', 'scan062data005.mat']
# /home/isabelle.bouchoule/Puce/analysedata/2024-04-24/scan062/
# Sélection des atomes : [ [ 10 140] [850 175] ]
# Sélection du background : [ [550 175] [650 185] ]
#
# Gain CCD: 0.9113504556752279
# 6
# _______________________________
# _______________________________
# Nom parametre : X1_bis : [np.uint16(350), np.uint16(400), np.uint16(450), np.uint16(500), np.uint16(550)]
# CPU times: user 14 µs, sys: 1e+03 ns, total: 15 µs
# Wall time: 20.5 µs
# -----
# ----
# -----
# ----
# offset =  595
# (350.0,) ['/media/pucemanip/manip/data/2024-04-24/scan062/scan062data001.mat']
# para X1_bis : 350.0 ;  (350.0,) 1
# N ph ,  3872.3021917174556
# /home/isabelle.bouchoule/.local/lib/python3.10/site-packages/matplotlib/cbook.py:1762: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /home/isabelle.bouchoule/.local/lib/python3.10/site-packages/matplotlib/cbook.py:1398: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# (400.0,) ['/media/pucemanip/manip/data/2024-04-24/scan062/scan062data002.mat']
# para X1_bis : 400.0 ;  (400.0,) 1
# N ph ,  5263.653060145476
# (450.0,) ['/media/pucemanip/manip/data/2024-04-24/scan062/scan062data003.mat']
# para X1_bis : 450.0 ;  (450.0,) 1
# N ph ,  5076.226279853812
# (500.0,) ['/media/pucemanip/manip/data/2024-04-24/scan062/scan062data004.mat']
# para X1_bis : 500.0 ;  (500.0,) 1
# N ph ,  744.7223825688174
# (550.0,) ['/media/pucemanip/manip/data/2024-04-24/scan062/scan062data005.mat']
# para X1_bis : 550.0 ;  (550.0,) 1
# N ph ,  3263.31607224844
# 2024-04-24/Y_1D_Scan_62_X1_bis-350.0_.txt
# 2024-04-24/Y_1D_Scan_62_X1_bis-400.0_.txt
# 2024-04-24/Y_1D_Scan_62_X1_bis-450.0_.txt
# 2024-04-24/Y_1D_Scan_62_X1_bis-500.0_.txt
# 2024-04-24/Y_1D_Scan_62_X1_bis-550.0_.txt
# la
# la 1
# la 2
# la 3
# CPU times: user 70 µs, sys: 0 ns, total: 70 µs
# Wall time: 77.7 µs

# %%
import numpy as np
import scipy as sp

import scipy
print(scipy.__version__)


date = '2024-04-24'

scans = np.array([62])
#scans = np.array([89])
scan=scans[0]

fichier = f"/media/pucemanip/manip/data/{date}/scan{str(scan).zfill(3)}/scan{str(scan).zfill(3)}data001.mat"
#fichier = f"/home/isabellebouchoule/Puce/analysedata/{date}/scan{str(scan).zfill(3)}/scan{str(scan).zfill(3)}data001.mat"
lesparams = sp.io.loadmat(fichier)['gusparam'][0]
#print(sorted([lesparams[2*i][0] for i in range(int(len(lesparams)/2))]))
param_names = [ 'X1_bis']  # List of parameter names
for param in param_names :
    if  param not in lesparams : print( f"{param} not in lesparams" )


def corresp(liste0):
    
    # Demander à l'utilisateur de saisir une série de lettres
    entree = input("Entrez une série de lettres : ").lower()
    
    # Liste dynamique des éléments dans lesparams correspondant à l'entrée
    correspondances = []
    
    # Parcourir les paramètres dans lesparams (ou liste0) et vérifier la correspondance avec l'entrée
    for param in lesparams:
        # Si l'entrée est dans le nom du paramètre (insensible à la casse)
        if isinstance(param[0], str) and entree in param[0].lower():
            correspondances.append(param[0])
    
    # Affichage des résultats
    if correspondances:
        print("Les éléments qui correspondent à votre entrée sont :")
        for item in correspondances:
            print(item)
    else:
        print(f"Aucune correspondance trouvée pour '{entree}'.")


corresp(lesparams)
# Out:
# 1.14.1
# Entrez une série de lettres :  Wi
# Les éléments qui correspondent à votre entrée sont :
# Width
# Width1

# %%
# %run Import_donnees_n_parametres.ipynb
# Out:
# Version de Python: 3.10.12
#
# Isat= 16.635141621871774
#
#  ['scan062data001.mat', 'scan062data002.mat', 'scan062data003.mat', 'scan062data004.mat', 'scan062data005.mat']
# /home/isabelle.bouchoule/Puce/analysedata/2024-04-24/scan062/
# Sélection des atomes : [ [ 10 140] [850 175] ]
# Sélection du background : [ [550 175] [650 185] ]
#
# Gain CCD: 0.9113504556752279
# 6
# _______________________________
# _______________________________
# Nom parametre : X1_bis : [np.uint16(350), np.uint16(400), np.uint16(450), np.uint16(500), np.uint16(550)]
# CPU times: user 34 µs, sys: 0 ns, total: 34 µs
# Wall time: 42 µs
# -----
# ----
# -----
# ----
# offset =  595
# (350.0,) ['/media/pucemanip/manip/data/2024-04-24/scan062/scan062data001.mat']
# para X1_bis : 350.0 ;  (350.0,) 1
# N ph ,  3872.3021917174556
# /home/isabelle.bouchoule/.local/lib/python3.10/site-packages/matplotlib/cbook.py:1762: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /home/isabelle.bouchoule/.local/lib/python3.10/site-packages/matplotlib/cbook.py:1398: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# (400.0,) ['/media/pucemanip/manip/data/2024-04-24/scan062/scan062data002.mat']
# para X1_bis : 400.0 ;  (400.0,) 1
# N ph ,  5263.653060145476
# (450.0,) ['/media/pucemanip/manip/data/2024-04-24/scan062/scan062data003.mat']
# para X1_bis : 450.0 ;  (450.0,) 1
# N ph ,  5076.226279853812
# (500.0,) ['/media/pucemanip/manip/data/2024-04-24/scan062/scan062data004.mat']
# para X1_bis : 500.0 ;  (500.0,) 1
# N ph ,  744.7223825688174
# (550.0,) ['/media/pucemanip/manip/data/2024-04-24/scan062/scan062data005.mat']
# para X1_bis : 550.0 ;  (550.0,) 1
# N ph ,  3263.31607224844
# 2024-04-24/Y_1D_Scan_62_X1_bis-350.0_.txt
# 2024-04-24/Y_1D_Scan_62_X1_bis-400.0_.txt
# 2024-04-24/Y_1D_Scan_62_X1_bis-450.0_.txt
# 2024-04-24/Y_1D_Scan_62_X1_bis-500.0_.txt
# 2024-04-24/Y_1D_Scan_62_X1_bis-550.0_.txt
# la
# la 1
# la 2
# la 3
# CPU times: user 79 µs, sys: 0 ns, total: 79 µs
# Wall time: 84.4 µs

# %%
import numpy as np
import scipy as sp

import scipy
print(scipy.__version__)


date = '2024-04-24'

scans = np.array([89,97,102,108])
#scans = np.array([89])
scan=scans[0]

fichier = f"/media/pucemanip/manip/data/{date}/scan{str(scan).zfill(3)}/scan{str(scan).zfill(3)}data001.mat"
#fichier = f"/home/isabellebouchoule/Puce/analysedata/{date}/scan{str(scan).zfill(3)}/scan{str(scan).zfill(3)}data001.mat"
lesparams = sp.io.loadmat(fichier)['gusparam'][0]
#print(sorted([lesparams[2*i][0] for i in range(int(len(lesparams)/2))]))
param_names = [ 'Width' , 'Height'   , "DeadtimeDMD_bis" , 'Width1', "Width1_bis", "DeadtimeDMD",'delta','RFfreqACfinexp',"Ismalldprquartic","Ismalldquartic","BxMOT"]  # List of parameter names
for param in param_names :
    if  param not in lesparams : print( f"{param} not in lesparams" )


def corresp(liste0):
    
    # Demander à l'utilisateur de saisir une série de lettres
    entree = input("Entrez une série de lettres : ").lower()
    
    # Liste dynamique des éléments dans lesparams correspondant à l'entrée
    correspondances = []
    
    # Parcourir les paramètres dans lesparams (ou liste0) et vérifier la correspondance avec l'entrée
    for param in lesparams:
        # Si l'entrée est dans le nom du paramètre (insensible à la casse)
        if isinstance(param[0], str) and entree in param[0].lower():
            correspondances.append(param[0])
    
    # Affichage des résultats
    if correspondances:
        print("Les éléments qui correspondent à votre entrée sont :")
        for item in correspondances:
            print(item)
    else:
        print(f"Aucune correspondance trouvée pour '{entree}'.")


corresp(lesparams)
# Out:
# 1.14.1
# Entrez une série de lettres :  H
# Les éléments qui correspondent à votre entrée sont :
# alphaI
# alphax
# alphay
# IzoffDCthree
# ACDCZbiasthree
# TimeoffDCthree
# RFshieldtime
# Tbreathing
# DelaichampZtrap
# RFshieldramptime
# RFfreqshield
# pulselength
# RFfreqACshield
# IDprharmonic
# timeflight
# pulselengthpump
# Height
# Width
# Width1
# Width1_bis

# %%
# %run Import_donnees_n_parametres.ipynb
# Out:
# Version de Python: 3.10.12
#
# Isat= 16.635141621871774
#
#  ['scan089data001.mat', 'scan089data002.mat', 'scan089data003.mat', 'scan089data004.mat', 'scan089data005.mat', 'scan089data006.mat', 'scan089data007.mat', 'scan089data008.mat', 'scan089data009.mat', 'scan089data010.mat', 'scan089data011.mat', 'scan089data012.mat', 'scan089data013.mat', 'scan089data014.mat', 'scan089data015.mat', 'scan089data016.mat', 'scan089data017.mat', 'scan089data018.mat', 'scan089data019.mat', 'scan089data020.mat', 'scan089data021.mat', 'scan089data022.mat', 'scan089data023.mat', 'scan089data024.mat', 'scan089data025.mat', 'scan089data026.mat', 'scan089data027.mat', 'scan089data028.mat', 'scan089data029.mat', 'scan089data030.mat', 'scan089data031.mat', 'scan089data032.mat', 'scan089data033.mat', 'scan089data034.mat', 'scan089data035.mat', 'scan089data036.mat', 'scan089data037.mat', 'scan089data038.mat', 'scan089data039.mat', 'scan089data040.mat', 'scan089data041.mat', 'scan089data042.mat', 'scan089data043.mat']
#
#  ['scan097data001.mat', 'scan097data002.mat', 'scan097data003.mat', 'scan097data004.mat', 'scan097data005.mat', 'scan097data006.mat', 'scan097data007.mat']
#
#  ['scan102data001.mat', 'scan102data002.mat', 'scan102data003.mat', 'scan102data004.mat', 'scan102data005.mat', 'scan102data006.mat', 'scan102data007.mat', 'scan102data008.mat', 'scan102data009.mat', 'scan102data010.mat', 'scan102data011.mat', 'scan102data012.mat', 'scan102data013.mat', 'scan102data014.mat', 'scan102data015.mat', 'scan102data016.mat', 'scan102data017.mat', 'scan102data018.mat', 'scan102data019.mat', 'scan102data020.mat', 'scan102data021.mat', 'scan102data022.mat', 'scan102data023.mat', 'scan102data024.mat', 'scan102data025.mat', 'scan102data026.mat', 'scan102data027.mat', 'scan102data028.mat', 'scan102data029.mat', 'scan102data030.mat', 'scan102data031.mat', 'scan102data032.mat', 'scan102data033.mat', 'scan102data034.mat', 'scan102data035.mat', 'scan102data036.mat', 'scan102data037.mat', 'scan102data038.mat', 'scan102data039.mat', 'scan102data040.mat', 'scan102data041.mat', 'scan102data042.mat', 'scan102data043.mat', 'scan102data044.mat', 'scan102data045.mat', 'scan102data046.mat', 'scan102data047.mat', 'scan102data048.mat', 'scan102data049.mat', 'scan102data050.mat', 'scan102data051.mat', 'scan102data052.mat', 'scan102data053.mat', 'scan102data054.mat', 'scan102data055.mat', 'scan102data056.mat', 'scan102data057.mat', 'scan102data058.mat', 'scan102data059.mat', 'scan102data060.mat', 'scan102data061.mat', 'scan102data062.mat', 'scan102data063.mat', 'scan102data064.mat', 'scan102data065.mat', 'scan102data066.mat', 'scan102data067.mat', 'scan102data068.mat', 'scan102data069.mat', 'scan102data070.mat', 'scan102data071.mat', 'scan102data072.mat', 'scan102data073.mat', 'scan102data074.mat', 'scan102data075.mat', 'scan102data076.mat', 'scan102data077.mat', 'scan102data078.mat', 'scan102data079.mat', 'scan102data080.mat', 'scan102data081.mat', 'scan102data082.mat', 'scan102data083.mat', 'scan102data084.mat', 'scan102data085.mat', 'scan102data086.mat', 'scan102data087.mat', 'scan102data088.mat', 'scan102data089.mat', 'scan102data090.mat', 'scan102data091.mat', 'scan102data092.mat', 'scan102data093.mat', 'scan102data094.mat', 'scan102data095.mat', 'scan102data096.mat', 'scan102data097.mat', 'scan102data098.mat', 'scan102data099.mat', 'scan102data100.mat', 'scan102data101.mat', 'scan102data102.mat', 'scan102data103.mat', 'scan102data104.mat', 'scan102data105.mat', 'scan102data106.mat', 'scan102data107.mat', 'scan102data108.mat', 'scan102data109.mat', 'scan102data110.mat', 'scan102data111.mat', 'scan102data112.mat', 'scan102data113.mat', 'scan102data114.mat', 'scan102data115.mat', 'scan102data116.mat', 'scan102data117.mat', 'scan102data118.mat', 'scan102data119.mat', 'scan102data120.mat', 'scan102data121.mat', 'scan102data122.mat', 'scan102data123.mat', 'scan102data124.mat', 'scan102data125.mat', 'scan102data126.mat', 'scan102data127.mat', 'scan102data128.mat', 'scan102data129.mat', 'scan102data130.mat', 'scan102data131.mat', 'scan102data132.mat', 'scan102data133.mat', 'scan102data134.mat', 'scan102data135.mat', 'scan102data136.mat', 'scan102data137.mat', 'scan102data138.mat', 'scan102data139.mat', 'scan102data140.mat', 'scan102data141.mat', 'scan102data142.mat', 'scan102data143.mat', 'scan102data144.mat', 'scan102data145.mat', 'scan102data146.mat', 'scan102data147.mat', 'scan102data148.mat', 'scan102data149.mat', 'scan102data150.mat', 'scan102data151.mat', 'scan102data152.mat', 'scan102data153.mat', 'scan102data154.mat', 'scan102data155.mat', 'scan102data156.mat', 'scan102data157.mat', 'scan102data158.mat', 'scan102data159.mat', 'scan102data160.mat', 'scan102data161.mat', 'scan102data162.mat', 'scan102data163.mat', 'scan102data164.mat', 'scan102data165.mat', 'scan102data166.mat', 'scan102data167.mat', 'scan102data168.mat', 'scan102data169.mat', 'scan102data170.mat', 'scan102data171.mat', 'scan102data172.mat', 'scan102data173.mat', 'scan102data174.mat', 'scan102data175.mat', 'scan102data176.mat', 'scan102data177.mat', 'scan102data178.mat', 'scan102data179.mat', 'scan102data180.mat', 'scan102data181.mat', 'scan102data182. ...
#
#  ['scan108data001.mat', 'scan108data002.mat', 'scan108data003.mat', 'scan108data004.mat', 'scan108data005.mat', 'scan108data006.mat', 'scan108data007.mat', 'scan108data008.mat', 'scan108data009.mat', 'scan108data010.mat', 'scan108data011.mat', 'scan108data012.mat', 'scan108data013.mat', 'scan108data014.mat', 'scan108data015.mat', 'scan108data016.mat', 'scan108data017.mat', 'scan108data018.mat', 'scan108data019.mat', 'scan108data020.mat', 'scan108data021.mat', 'scan108data022.mat', 'scan108data023.mat', 'scan108data024.mat', 'scan108data025.mat', 'scan108data026.mat', 'scan108data027.mat', 'scan108data028.mat', 'scan108data029.mat', 'scan108data030.mat', 'scan108data031.mat', 'scan108data032.mat', 'scan108data033.mat', 'scan108data034.mat', 'scan108data035.mat', 'scan108data036.mat', 'scan108data037.mat', 'scan108data038.mat', 'scan108data039.mat', 'scan108data040.mat', 'scan108data041.mat', 'scan108data042.mat', 'scan108data043.mat', 'scan108data044.mat', 'scan108data045.mat', 'scan108data046.mat', 'scan108data047.mat', 'scan108data048.mat', 'scan108data049.mat', 'scan108data050.mat', 'scan108data051.mat', 'scan108data052.mat', 'scan108data053.mat', 'scan108data054.mat', 'scan108data055.mat', 'scan108data056.mat', 'scan108data057.mat', 'scan108data058.mat', 'scan108data059.mat', 'scan108data060.mat', 'scan108data061.mat', 'scan108data062.mat', 'scan108data063.mat', 'scan108data064.mat', 'scan108data065.mat', 'scan108data066.mat', 'scan108data067.mat', 'scan108data068.mat', 'scan108data069.mat', 'scan108data070.mat', 'scan108data071.mat', 'scan108data072.mat', 'scan108data073.mat', 'scan108data074.mat', 'scan108data075.mat', 'scan108data076.mat', 'scan108data077.mat', 'scan108data078.mat', 'scan108data079.mat', 'scan108data080.mat', 'scan108data081.mat', 'scan108data082.mat', 'scan108data083.mat', 'scan108data084.mat', 'scan108data085.mat', 'scan108data086.mat', 'scan108data087.mat', 'scan108data088.mat', 'scan108data089.mat', 'scan108data090.mat', 'scan108data091.mat', 'scan108data092.mat', 'scan108data093.mat', 'scan108data094.mat', 'scan108data095.mat', 'scan108data096.mat', 'scan108data097.mat', 'scan108data098.mat', 'scan108data099.mat', 'scan108data100.mat', 'scan108data101.mat', 'scan108data102.mat', 'scan108data103.mat', 'scan108data104.mat', 'scan108data105.mat', 'scan108data106.mat', 'scan108data107.mat', 'scan108data108.mat', 'scan108data109.mat', 'scan108data110.mat', 'scan108data111.mat', 'scan108data112.mat', 'scan108data113.mat', 'scan108data114.mat', 'scan108data115.mat', 'scan108data116.mat', 'scan108data117.mat', 'scan108data118.mat', 'scan108data119.mat']
# /home/isabelle.bouchoule/Puce/analysedata/2024-04-24/scan089/
# Sélection des atomes : [ [ 10 140] [850 175] ]
# Sélection du background : [ [550 175] [650 185] ]
#
# Gain CCD: 0.9113504556752279
# 44
# 8
# 188
# 120
# _______________________________
# _______________________________
# Nom parametre : Width : [np.uint16(1500)]
# Nom parametre : Height : [np.uint8(10)]
# Nom parametre : DeadtimeDMD_bis : [np.float64(0.5), np.uint8(30)]
# Nom parametre : Width1 : [np.uint16(1500), np.uint8(0), np.uint16(900)]
# Nom parametre : Width1_bis : [np.uint16(1500), np.uint8(50)]
# Nom parametre : DeadtimeDMD : [np.float64(0.5), np.uint8(18)]
# Nom parametre : delta : [np.int16(-78)]
# Nom parametre : RFfreqACfinexp : [np.uint16(2748)]
# Nom parametre : Ismalldprquartic : [np.float64(0.865)]
# Nom parametre : Ismalldquartic : [np.float64(1.09)]
# Nom parametre : BxMOT : [np.int16(-3), np.uint8(10)]
# CPU times: user 0 ns, sys: 26 µs, total: 26 µs
# Wall time: 42 µs
# -----
# ----
# -----
# ----
# offset =  595
# (1500.0, 10.0, 0.5, 1500.0, 1500.0, 0.5, -78.0, 2748.0, 0.865, 1.09, -3.0) ['/media/pucemanip/manip/data/2024-04-24/scan089/scan089data001.mat', '/media/pucemanip/manip/data/2024-04-24/scan089/scan089data019.mat', '/media/pucemanip/manip/data/2024-04-24/scan089/scan089data037.mat', '/media/pucemanip/manip/data/2024-04-24/scan097/scan097data001.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data001.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data019.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data037.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data055.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data073.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data091.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data109.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data127.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data145.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data163.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data181.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data001.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data011.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data021.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data031.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data041.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data051.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data061.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data071.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data081.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data091.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data101.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data111.mat']
# para Width : 1500.0 ; Height : 10.0 ; DeadtimeDMD_bis : 0.5 ; Width1 : 1500.0 ; Width1_bis : 1500.0 ; DeadtimeDMD : 0.5 ; delta : -78.0 ; RFfreqACfinexp : 2748.0 ; Ismalldprquartic : 0.865 ; Ismalldquartic : 1.09 ; BxMOT : -3.0 ;  (1500.0, 10.0, 0.5, 1500.0, 1500.0, 0.5, -78.0, 2748.0, 0.865, 1.09, -3.0) 27
# N ph ,  18070.438893231967
# (1500.0, 10.0, 0.5, 0.0, 1500.0, 0.5, -78.0, 2748.0, 0.865, 1.09, -3.0) ['/media/pucemanip/manip/data/2024-04-24/scan089/scan089data002.mat', '/media/pucemanip/manip/data/2024-04-24/scan089/scan089data020.mat', '/media/pucemanip/manip/data/2024-04-24/scan089/scan089data038.mat', '/media/pucemanip/manip/data/2024-04-24/scan097/scan097data002.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data002.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data020.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data038.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data056.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data074.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data092.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data110.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data128.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data146.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data164.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data182.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data002.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data003.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data012.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data013.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data022.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data023.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data032.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data033.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data042.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data043.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data052.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data053.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data062.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data063.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data072.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data073.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data082.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data083.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data092.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data093.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data102.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data103.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data112.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data113.mat']
# para Width : 1500.0 ; Height : 10.0 ; DeadtimeDMD_bis : 0.5 ; Width1 : 0.0 ; Width1_bis : 1500.0 ; DeadtimeDMD : 0.5 ; delta : -78.0 ; RFfreqACfinexp : 2748.0 ; Ismalldprquartic : 0.865 ; Ismalldquartic : 1.09 ; BxMOT : -3.0 ;  (1500.0, 10.0, 0.5, 0.0, 1500.0, 0.5, -78.0, 2748.0, 0.865, 1.09, -3.0) 39
# N ph ,  4393.480064739404
# (1500.0, 10.0, 0.5, 900.0, 1500.0, 0.5, -78.0, 2748.0, 0.865, 1.09, -3.0) ['/media/pucemanip/manip/data/2024-04-24/scan089/scan089data003.mat', '/media/pucemanip/manip/data/2024-04-24/scan089/scan089data021.mat', '/media/pucemanip/manip/data/2024-04-24/scan089/scan089data039.mat', '/media/pucemanip/manip/data/2024-04-24/scan097/scan097data003.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data003.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data021.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data039.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data057.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data075.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data093.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data111.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data129.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data147.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data165.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data183.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data004.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data014.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data024.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data034.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data044.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data054.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data064.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data074.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data084.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data094.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data104.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data114.mat']
# para Width : 1500.0 ; Height : 10.0 ; DeadtimeDMD_bis : 0.5 ; Width1 : 900.0 ; Width1_bis : 1500.0 ; DeadtimeDMD : 0.5 ; delta : -78.0 ; RFfreqACfinexp : 2748.0 ; Ismalldprquartic : 0.865 ; Ismalldquartic : 1.09 ; BxMOT : -3.0 ;  (1500.0, 10.0, 0.5, 900.0, 1500.0, 0.5, -78.0, 2748.0, 0.865, 1.09, -3.0) 27
# N ph ,  15640.373690120665
# (1500.0, 10.0, 0.5, 900.0, 1500.0, 18.0, -78.0, 2748.0, 0.865, 1.09, -3.0) ['/media/pucemanip/manip/data/2024-04-24/scan108/scan108data006.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data007.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data016.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data017.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data026.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data027.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data036.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data037.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data046.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data047.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data056.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data057.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data066.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data067.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data076.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data077.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data086.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data087.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data096.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data097.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data106.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data107.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data116.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data117.mat']
# para Width : 1500.0 ; Height : 10.0 ; DeadtimeDMD_bis : 0.5 ; Width1 : 900.0 ; Width1_bis : 1500.0 ; DeadtimeDMD : 18.0 ; delta : -78.0 ; RFfreqACfinexp : 2748.0 ; Ismalldprquartic : 0.865 ; Ismalldquartic : 1.09 ; BxMOT : -3.0 ;  (1500.0, 10.0, 0.5, 900.0, 1500.0, 18.0, -78.0, 2748.0, 0.865, 1.09, -3.0) 24
# N ph ,  13531.059471659772
# (1500.0, 10.0, 0.5, 900.0, 50.0, 18.0, -78.0, 2748.0, 0.865, 1.09, -3.0) ['/media/pucemanip/manip/data/2024-04-24/scan102/scan102data006.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data024.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data042.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data060.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data078.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data096.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data114.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data132.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data150.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data168.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data186.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data008.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data018.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data028.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data038.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data048.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data058.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data068.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data078.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data088.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data098.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data108.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data118.mat']
# para Width : 1500.0 ; Height : 10.0 ; DeadtimeDMD_bis : 0.5 ; Width1 : 900.0 ; Width1_bis : 50.0 ; DeadtimeDMD : 18.0 ; delta : -78.0 ; RFfreqACfinexp : 2748.0 ; Ismalldprquartic : 0.865 ; Ismalldquartic : 1.09 ; BxMOT : -3.0 ;  (1500.0, 10.0, 0.5, 900.0, 50.0, 18.0, -78.0, 2748.0, 0.865, 1.09, -3.0) 23
# N ph ,  5103.911486081599
# (1500.0, 10.0, 30.0, 900.0, 1500.0, 0.5, -78.0, 2748.0, 0.865, 1.09, -3.0) ['/media/pucemanip/manip/data/2024-04-24/scan097/scan097data005.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data005.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data023.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data041.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data059.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data077.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data095.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data113.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data131.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data149.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data167.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data185.mat']
# para Width : 1500.0 ; Height : 10.0 ; DeadtimeDMD_bis : 30.0 ; Width1 : 900.0 ; Width1_bis : 1500.0 ; DeadtimeDMD : 0.5 ; delta : -78.0 ; RFfreqACfinexp : 2748.0 ; Ismalldprquartic : 0.865 ; Ismalldquartic : 1.09 ; BxMOT : -3.0 ;  (1500.0, 10.0, 30.0, 900.0, 1500.0, 0.5, -78.0, 2748.0, 0.865, 1.09, -3.0) 12
# N ph ,  14973.009033204504
# (1500.0, 10.0, 30.0, 900.0, 1500.0, 0.5, -78.0, 2748.0, 0.865, 1.09, 10.0) ['/media/pucemanip/manip/data/2024-04-24/scan097/scan097data004.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data004.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data022.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data040.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data058.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data076.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data094.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data112.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data130.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data148.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data166.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data184.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data005.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data015.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data025.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data035.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data045.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data055.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data065.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data075.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data085.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data095.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data105.mat', '/media/pucemanip/manip/data/2024-04-24/scan108/scan108data115.mat']
# para Width : 1500.0 ; Height : 10.0 ; DeadtimeDMD_bis : 30.0 ; Width1 : 900.0 ; Width1_bis : 1500.0 ; DeadtimeDMD : 0.5 ; delta : -78.0 ; RFfreqACfinexp : 2748.0 ; Ismalldprquartic : 0.865 ; Ismalldquartic : 1.09 ; BxMOT : 10.0 ;  (1500.0, 10.0, 30.0, 900.0, 1500.0, 0.5, -78.0, 2748.0, 0.865, 1.09, 10.0) 24
# N ph ,  5433.294450515155
# (1500.0, 10.0, 30.0, 900.0, 1500.0, 18.0, -78.0, 2748.0, 0.865, 1.09, -3.0) ['/media/pucemanip/manip/data/2024-04-24/scan089/scan089data005.mat', '/media/pucemanip/manip/data/2024-04-24/scan089/scan089data023.mat', '/media/pucemanip/manip/data/2024-04-24/scan089/scan089data041.mat']
# para Width : 1500.0 ; Height : 10.0 ; DeadtimeDMD_bis : 30.0 ; Width1 : 900.0 ; Width1_bis : 1500.0 ; DeadtimeDMD : 18.0 ; delta : -78.0 ; RFfreqACfinexp : 2748.0 ; Ismalldprquartic : 0.865 ; Ismalldquartic : 1.09 ; BxMOT : -3.0 ;  (1500.0, 10.0, 30.0, 900.0, 1500.0, 18.0, -78.0, 2748.0, 0.865, 1.09, -3.0) 3
# N ph ,  16848.981078507888
# (1500.0, 10.0, 30.0, 900.0, 1500.0, 18.0, -78.0, 2748.0, 0.865, 1.09, 10.0) ['/media/pucemanip/manip/data/2024-04-24/scan089/scan089data004.mat', '/media/pucemanip/manip/data/2024-04-24/scan089/scan089data022.mat', '/media/pucemanip/manip/data/2024-04-24/scan089/scan089data040.mat']
# para Width : 1500.0 ; Height : 10.0 ; DeadtimeDMD_bis : 30.0 ; Width1 : 900.0 ; Width1_bis : 1500.0 ; DeadtimeDMD : 18.0 ; delta : -78.0 ; RFfreqACfinexp : 2748.0 ; Ismalldprquartic : 0.865 ; Ismalldquartic : 1.09 ; BxMOT : 10.0 ;  (1500.0, 10.0, 30.0, 900.0, 1500.0, 18.0, -78.0, 2748.0, 0.865, 1.09, 10.0) 3
# N ph ,  3537.964292757314
# (1500.0, 10.0, 30.0, 900.0, 50.0, 0.5, -78.0, 2748.0, 0.865, 1.09, -3.0) ['/media/pucemanip/manip/data/2024-04-24/scan097/scan097data006.mat']
# para Width : 1500.0 ; Height : 10.0 ; DeadtimeDMD_bis : 30.0 ; Width1 : 900.0 ; Width1_bis : 50.0 ; DeadtimeDMD : 0.5 ; delta : -78.0 ; RFfreqACfinexp : 2748.0 ; Ismalldprquartic : 0.865 ; Ismalldquartic : 1.09 ; BxMOT : -3.0 ;  (1500.0, 10.0, 30.0, 900.0, 50.0, 0.5, -78.0, 2748.0, 0.865, 1.09, -3.0) 1
# N ph ,  4618.023655571745
# (1500.0, 10.0, 30.0, 900.0, 50.0, 18.0, -78.0, 2748.0, 0.865, 1.09, -3.0) ['/media/pucemanip/manip/data/2024-04-24/scan089/scan089data006.mat', '/media/pucemanip/manip/data/2024-04-24/scan089/scan089data007.mat', '/media/pucemanip/manip/data/2024-04-24/scan089/scan089data008.mat', '/media/pucemanip/manip/data/2024-04-24/scan089/scan089data009.mat', '/media/pucemanip/manip/data/2024-04-24/scan089/scan089data010.mat', '/media/pucemanip/manip/data/2024-04-24/scan089/scan089data011.mat', '/media/pucemanip/manip/data/2024-04-24/scan089/scan089data012.mat', '/media/pucemanip/manip/data/2024-04-24/scan089/scan089data013.mat', '/media/pucemanip/manip/data/2024-04-24/scan089/scan089data014.mat', '/media/pucemanip/manip/data/2024-04-24/scan089/scan089data015.mat', '/media/pucemanip/manip/data/2024-04-24/scan089/scan089data016.mat', '/media/pucemanip/manip/data/2024-04-24/scan089/scan089data017.mat', '/media/pucemanip/manip/data/2024-04-24/scan089/scan089data018.mat', '/media/pucemanip/manip/data/2024-04-24/scan089/scan089data024.mat', '/media/pucemanip/manip/data/2024-04-24/scan089/scan089data025.mat', '/media/pucemanip/manip/data/2024-04-24/scan089/scan089data026.mat', '/media/pucemanip/manip/data/2024-04-24/scan089/scan089data027.mat', '/media/pucemanip/manip/data/2024-04-24/scan089/scan089data028.mat', '/media/pucemanip/manip/data/2024-04-24/scan089/scan089data029.mat', '/media/pucemanip/manip/data/2024-04-24/scan089/scan089data030.mat', '/media/pucemanip/manip/data/2024-04-24/scan089/scan089data031.mat', '/media/pucemanip/manip/data/2024-04-24/scan089/scan089data032.mat', '/media/pucemanip/manip/data/2024-04-24/scan089/scan089data033.mat', '/media/pucemanip/manip/data/2024-04-24/scan089/scan089data034.mat', '/media/pucemanip/manip/data/2024-04-24/scan089/scan089data035.mat', '/media/pucemanip/manip/data/2024-04-24/scan089/scan089data036.mat', '/media/pucemanip/manip/data/2024-04-24/scan089/scan089data042.mat', '/media/pucemanip/manip/data/2024-04-24/scan089/scan089data043.mat', '/media/pucemanip/manip/data/2024-04-24/scan097/scan097data007.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data007.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data008.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data009.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data010.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data011.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data012.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data013.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data014.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data015.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data016.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data017.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data018.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data025.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data026.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data027.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data028.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data029.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data030.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data031.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data032.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data033.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data034.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data035.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data036.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data043.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data044.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data045.mat', '/media/pucemanip/manip/data/2024-04-24/scan102/scan102data04 ...
# para Width : 1500.0 ; Height : 10.0 ; DeadtimeDMD_bis : 30.0 ; Width1 : 900.0 ; Width1_bis : 50.0 ; DeadtimeDMD : 18.0 ; delta : -78.0 ; RFfreqACfinexp : 2748.0 ; Ismalldprquartic : 0.865 ; Ismalldquartic : 1.09 ; BxMOT : -3.0 ;  (1500.0, 10.0, 30.0, 900.0, 50.0, 18.0, -78.0, 2748.0, 0.865, 1.09, -3.0) 173
# N ph ,  6129.562104140239
# 2024-04-24/Y_1D_Scan_89_Width-1500.0_Height-10.0_DeadtimeDMD_bis-0.5_Width1-1500.0_Width1_bis-1500.0_DeadtimeDMD-0.5_delta--78.0_RFfreqACfinexp-2748.0_Ismalldprquartic-0.865_Ismalldquartic-1.09_BxMOT--3.0_.txt
# 2024-04-24/Y_1D_Scan_89_Width-1500.0_Height-10.0_DeadtimeDMD_bis-0.5_Width1-0.0_Width1_bis-1500.0_DeadtimeDMD-0.5_delta--78.0_RFfreqACfinexp-2748.0_Ismalldprquartic-0.865_Ismalldquartic-1.09_BxMOT--3.0_.txt
# 2024-04-24/Y_1D_Scan_89_Width-1500.0_Height-10.0_DeadtimeDMD_bis-0.5_Width1-900.0_Width1_bis-1500.0_DeadtimeDMD-0.5_delta--78.0_RFfreqACfinexp-2748.0_Ismalldprquartic-0.865_Ismalldquartic-1.09_BxMOT--3.0_.txt
# 2024-04-24/Y_1D_Scan_89_Width-1500.0_Height-10.0_DeadtimeDMD_bis-0.5_Width1-900.0_Width1_bis-1500.0_DeadtimeDMD-18.0_delta--78.0_RFfreqACfinexp-2748.0_Ismalldprquartic-0.865_Ismalldquartic-1.09_BxMOT--3.0_.txt
# 2024-04-24/Y_1D_Scan_89_Width-1500.0_Height-10.0_DeadtimeDMD_bis-0.5_Width1-900.0_Width1_bis-50.0_DeadtimeDMD-18.0_delta--78.0_RFfreqACfinexp-2748.0_Ismalldprquartic-0.865_Ismalldquartic-1.09_BxMOT--3.0_.txt
# 2024-04-24/Y_1D_Scan_89_Width-1500.0_Height-10.0_DeadtimeDMD_bis-30.0_Width1-900.0_Width1_bis-1500.0_DeadtimeDMD-0.5_delta--78.0_RFfreqACfinexp-2748.0_Ismalldprquartic-0.865_Ismalldquartic-1.09_BxMOT--3.0_.txt
# 2024-04-24/Y_1D_Scan_89_Width-1500.0_Height-10.0_DeadtimeDMD_bis-30.0_Width1-900.0_Width1_bis-1500.0_DeadtimeDMD-0.5_delta--78.0_RFfreqACfinexp-2748.0_Ismalldprquartic-0.865_Ismalldquartic-1.09_BxMOT-10.0_.txt
# 2024-04-24/Y_1D_Scan_89_Width-1500.0_Height-10.0_DeadtimeDMD_bis-30.0_Width1-900.0_Width1_bis-1500.0_DeadtimeDMD-18.0_delta--78.0_RFfreqACfinexp-2748.0_Ismalldprquartic-0.865_Ismalldquartic-1.09_BxMOT--3.0_.txt
# 2024-04-24/Y_1D_Scan_89_Width-1500.0_Height-10.0_DeadtimeDMD_bis-30.0_Width1-900.0_Width1_bis-1500.0_DeadtimeDMD-18.0_delta--78.0_RFfreqACfinexp-2748.0_Ismalldprquartic-0.865_Ismalldquartic-1.09_BxMOT-10.0_.txt
# 2024-04-24/Y_1D_Scan_89_Width-1500.0_Height-10.0_DeadtimeDMD_bis-30.0_Width1-900.0_Width1_bis-50.0_DeadtimeDMD-0.5_delta--78.0_RFfreqACfinexp-2748.0_Ismalldprquartic-0.865_Ismalldquartic-1.09_BxMOT--3.0_.txt
# 2024-04-24/Y_1D_Scan_89_Width-1500.0_Height-10.0_DeadtimeDMD_bis-30.0_Width1-900.0_Width1_bis-50.0_DeadtimeDMD-18.0_delta--78.0_RFfreqACfinexp-2748.0_Ismalldprquartic-0.865_Ismalldquartic-1.09_BxMOT--3.0_.txt
# la
# la 1
# la 2
# la 3
# CPU times: user 98 µs, sys: 11 µs, total: 109 µs
# Wall time: 116 µs

# %%
import scipy.signal as signal
from numpy.polynomial.polynomial import Polynomial
from scipy.interpolate import lagrange
X1 , Y1 , label1 = PROFILS[8]
plt.plot(X1,signal.savgol_filter(Y1,20 , 1 ) , label = label1 )
X1 , Y1 , label1 = PROFILS[1]
plt.plot(X1,signal.savgol_filter(Y1,20 , 1 ) , label = label1 )
X1 , Y1 , label1 = PROFILS[6]
plt.plot(X1,signal.savgol_filter(Y1,20 , 1 ) , label = label1 )
X1 , Y1 , label1 = PROFILS[9]
plt.plot(X1,signal.savgol_filter(Y1,20 , 1 ) , label = label1 )
X1 , Y1 , label1 = PROFILS[10]
plt.plot(X1,Y1 , label = label1 )
plt.legend(
    loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))
plt.show()

X0 , Y0 , label0 = PROFILS[6]
#Y0 = np.genfromtxt("2024-04-24/Y_1D_Scan_29_delta--79.0_.txt")
Y0 = signal.savgol_filter(Y0 ,15 , 3 )
plt.plot(X0,Y0 , label = label0 )
plt.plot(X0,Y1  , label = label0 )
plt.plot(X0,Y1 - Y0  , label = label0 )
plt.legend(
    loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))
plt.show()


mask = (X1 < 700) + (X1 >1200)
X1filter , Y1filter = X1[mask] , signal.savgol_filter(Y1,20 , 1 )[mask] 
liste_ind = [ 50,  250 ,  500 , 550 , 600 ,  650 ,699]
liste_ind = [ 10, 100, 250 , 500, 600, 699]
liste_ind = [  100, 200, 550, 600]
#liste_ind = [i for i in range (len(mask)) if mask[i] ]
X1filter , Y1filter = X1 , Polynomial(lagrange([X1[i] for i in liste_ind] , [signal.savgol_filter(Y1,20 , 3 )[i] for i in liste_ind]).coef[::-1])(X1) 
#Y1filter = Y0 + 1
plt.plot(X1filter , Y1filter , label = 'filtre 1 ' )
Y0filter = signal.savgol_filter(Y0 ,200 , 1 )

#poly = lagrange(x, y)
#plt.plot(X0, Y0filter , label = "fond" )

plt.plot(X1 , Y1 - Y1filter)
#plt.ylim([-1 , 3 ])

plt.legend(
    loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))
plt.show()

X , Y , label = PROFILS[0]
plt.plot(X,Y-Y1filter , label = label )
X , Y , label = PROFILS[2]
plt.plot(X,Y-Y1filter , label = label )
X , Y , label = PROFILS[5]
plt.plot(X,Y-Y1filter , label = label )
X , Y , label = PROFILS[7]
plt.plot(X,Y-Y1filter , label = label )
print(sum(Y))
X , Y , label1 = PROFILS[-3]
plt.plot(X,Y-Y1filter , label = label )
print(sum(Y))
plt.legend(
    loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))
plt.show()
# Out:
# 12692.264465919307
# 2665.1331772183125

# %%
X1 , Y1 , label1 = PROFILS[10]
plt.plot(X1 , Y1 , label = "donné")
Xf , Yf , labelf = PROFILS[6]
plt.plot(Xf , Yf , label = "fond")
Xffilter1 , Yffilter1 = Xf , signal.savgol_filter(Yf,10 , 3 )
plt.plot(Xffilter1 , Yffilter1, label = "fond  1")

Xffilter11 , Yffilter11 = Xffilter1 , Yffilter1 + 0.12
plt.plot(Xffilter11 , Yffilter11, label = "fond  1.1")


from scipy.interpolate import interp1d
f = interp1d(Xffilter11, Yffilter11, kind='linear', fill_value='extrapolate')
    
mask = Xf > -1000
liste_X = [ 200, 550, 1400]
Xffilter2 , Yffilter2 = Xf , Polynomial(lagrange(liste_X , [f(x) for x in liste_X]).coef[::-1])(Xf) 
plt.plot(Xffilter2 , Yffilter2, label = "fond  2")

plt.legend(
    loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))
plt.show()

plt.plot( X1 , Y1 - Yffilter1 , label = "sans fond 1.0 ")
plt.plot( X1 , Y1 - Yffilter11 , label = "sans fond 1.1 ")
plt.plot( X1 , Y1 - Yffilter2 , label = "sans fond 2 ")

plt.legend(
    loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))
plt.show()

# %%
x0 = 0

X , Y , label = PROFILS[3]
plt.plot(X-x0,Y - Y0  , label = label )
#plt.show()

x , y = np.flip(X-x0) , Y-Y0

plt.plot(x,y , label = label )
#plt.show()

def model(x , A , sigma , x0 , b ):
    
    from scipy import special
    return A/2*(special.erf((x-x0)/sigma)+1) + b 

mask = (x > 0-x0)*(x < 850-x0) 
eps = 1e-3
yerr = np.full (len(y[mask]) , eps ) 


plt.plot(x[mask],y[mask] , label = label )
plt.show()
p0 = [ 30 , 1 , 800 , 0 ]
popt , pcov = curve_fit(model , x[mask] , y[mask] , sigma = yerr , p0 = np.array(p0), 
                            bounds = ([0, 0 , - 1000 , - 5  ],[100 , 100 , 1000 , 5 ])
                           )

#popt = p0
print(popt)
A , sigma , x0 , b = popt 
plt.plot( x  , y  , label = "donnés")
plt.plot( x , model(x , *popt) , label = "fit")
plt.legend()
plt.show()

PROFILS[3][1] = PROFILS[3][1] - b 
X , Y , label = PROFILS[3]

x , y = np.flip(X-x0) , Y-Y0

plt.plot(x[mask],y[mask] , label = label )
plt.show()




p0 = [ 30 , 1 , 60 , 0 ]
popt , pcov = curve_fit(model , x[mask] , y[mask] , sigma = yerr , p0 = np.array(p0), 
                            bounds = ([0, 0 , - 1000 , - 5  ],[100 , 100 , 1000 , 5 ])
                           )

#popt = p0
print(popt)
A , sigma , x0 , b = popt 
plt.plot( x  , y  , label = "donnés")
plt.plot( x , model(x , *popt) , label = "fit")
plt.legend()
plt.plot()
# Out:
# [ 55.97089196  67.34266311 694.60618296  -1.15075479]
# [ 5.59708518e+01  6.73423397e+01 -9.38687918e-06  8.53363905e-06]
# []

# %%
x0 = 0

X , Y , label = PROFILS[2]
plt.plot(X-x0,Y - Y0  , label = label )
#plt.show()

x , y = np.flip(X-x0) , Y-Y0

plt.plot(x,y , label = label )
#plt.show()

def model(x , A , sigma , x0 , b ):
    
    from scipy import special
    return A/2*(special.erf((x-x0)/sigma)+1) + b 

mask = (x > 0-x0)*(x < 800-x0) 
eps = 1e-3
yerr = np.full (len(y[mask]) , eps ) 


plt.plot(x[mask],y[mask] , label = label )
plt.show()
p0 = [ 30 , 1 , 800 , 0 ]
popt , pcov = curve_fit(model , x[mask] , y[mask] , sigma = yerr , p0 = np.array(p0), 
                            bounds = ([0, 0 , - 1000 , - 5  ],[100 , 100 , 1000 , 5 ])
                           )

#popt = p0
print(popt)
A , sigma , x0 , b = popt 
plt.plot( x  , y  , label = "donnés")
plt.plot( x , model(x , *popt) , label = "fit")
plt.legend()
plt.show()

PROFILS[2][1] = PROFILS[2][1] - b 
X , Y , label = PROFILS[2]

x , y = np.flip(X-x0) , Y-Y0

plt.plot(x[mask],y[mask] , label = label )
plt.show()




p0 = [ 30 , 1 , 60 , 0 ]
popt , pcov = curve_fit(model , x[mask] , y[mask] , sigma = yerr , p0 = np.array(p0), 
                            bounds = ([0, 0 , - 1000 , - 5  ],[100 , 100 , 1000 , 5 ])
                           )

#popt = p0
print(popt)
A , sigma , x00 , b = popt 
plt.plot( x  , y  , label = "donnés")
plt.plot( x , model(x , *popt) , label = "fit")
plt.legend()
plt.plot()
# Out:
# [ 68.20281549  20.35300096 697.22928843   1.15075523]
# [ 6.82028175e+01  2.03530089e+01  1.88147016e-06 -1.07361155e-07]
# []

# %%
x00 = 0

X , Y , label = PROFILS[4]
plt.plot(X-x00,Y - Y0  , label = label )
#plt.show()

x , y = np.flip(X-x00) , Y-Y0

plt.plot(x,y , label = label )
#plt.show()

def model(x , A , sigma , x0 , b ):
    
    from scipy import special
    return A/2*(np.exp(-(x-x0)**2/sigma**2)) + b 

mask = (x > 0-x00)*(x < 1400-x00) 
eps = 1e-3
yerr = np.full (len(y[mask]) , eps ) 


plt.plot(x[mask],y[mask] , label = label )
plt.show()
p0 = [ 100 , 100 , 650, 0 ]
popt , pcov = curve_fit(model , x[mask] , y[mask] , sigma = yerr , p0 = np.array(p0), 
                            bounds = ([0, 0 , 0 , - 5  ],[100 , 1000 , 1000 , 5 ])
                           )

#popt = p0
print(popt)
A , sigma , x00 , b = popt 
plt.plot( x  , y  , label = "donnés")
plt.plot( x , model(x , *popt) , label = "fit")
plt.legend()
plt.show()

PROFILS[4][1] = PROFILS[4][1] - b 
X , Y , label = PROFILS[4]

x , y = np.flip(X-x00) , Y-Y0

plt.plot(x[mask],y[mask] , label = label )
plt.show()




p0 = [ 100 , 100 , 0, 0 ]
popt , pcov = curve_fit(model , x[mask] , y[mask] , sigma = yerr , p0 = np.array(p0), 
                            bounds = ([0, 0 , - 1000 , - 5  ],[100 , 100 , 1000 , 5 ])
                           )

#popt = p0
print(popt)
A , sigma , x00 , b = popt 
plt.plot( x  , y  , label = "donnés")
plt.plot( x , model(x , *popt) , label = "fit")
plt.legend()
plt.plot()
# Out:
# [ 6.89990236e+01  1.59599821e+01  7.16086805e+02 -4.64072498e-01]
# [ 6.89990159e+01  1.59599858e+01 -8.17266912e-07 -9.57150482e-08]
# []

# %%
#x0 = 6.94903402e+02#6.95612617e+02
print("x0 :", x0)

def taille(X,Y):
    
    bord_gauche = X[np.argmax(np.gradient(Y))]
    bord_droite = X[np.argmin(np.gradient(Y))]
    print ("bord_gauche : ", bord_gauche , ' ; bord_droite :' , bord_droite)
    
    print((bord_gauche+bord_droite)/2)
    
    plt.plot(X,Y) 
    plt.plot(X,np.gradient(Y))
    plt.vlines(x=bord_droite, ymin=-1, ymax=20, colors='green', ls=':', lw=2)
    plt.vlines(x=bord_gauche, ymin=-1, ymax=20, colors='green', ls=':', lw=2)
    #plt.xlim([-50 , 50])
    plt.xlabel('x $(\mu m)$')
    #plt.show()
    
    Taille_exp = bord_droite - bord_gauche 
    print ("Taille bord" , Taille_exp)
    
    print("le nombre d'atome est " , np.sum(Y[Y>0])*pixelsize*1e6)
    



X0 , Y0 , label0 = PROFILS[6]
Y0 = signal.savgol_filter(Y0 ,15 , 3 )+ 1*b

import os

new_date = date
if not os.path.isdir(new_date):
    os.mkdir(new_date)
if not os.path.isdir(new_date+'/Donnees/'):
    os.mkdir(new_date+'/Donnees')
    

liste_ind = [0 , 2 , 3 ,4, 10 ]
nom_x = ["X_insitut","erreur","X_coupure1_1ms","X_coupure1_18ms","X_coupure2_1ms", "erreur","erreur","erreur","erreur","erreur","X_coupure2_30ms"]
nom_y = ["Y_insitut","erreur","Y_coupure1_1ms","Y_coupure1_18ms","Y_coupure2_1ms" ,"erreur","erreur","erreur","erreur","erreur","Y_coupure2_30ms"]
 
print("x0 :", x0)
for i in  liste_ind[1:]:
    X , Y , label = PROFILS[i]
    
    plt.plot(np.flip(X)-x0,Y - Y0  , label = nom_y[i] )#+ ' : ' +label )
    
    x1, y1 = -550, -5
    x2, y2 = 700, 5
    plt.xlim(x1, x2)  # Limite de X de 0 à 10
    plt.ylim(y1,y2)   # Limite de Y de 1 à 8
    #taille(np.flip(X)-x0,Y-Y0)
    # Définir les deux points (x1, y1) et (x2, y2)
    y10 , y20 = 0,0 
    x10 = 0 
    # Tracer la ligne pointillée en utilisant axline avec deux points
    plt.axline((x10, y10), slope=(y20 - y10) / (x2 - x1), color='blue', linestyle='--')
    # Tracer la ligne pointillée en utilisant axline avec deux points
    plt.axvline(x=x10, color='blue', linestyle='--')
  
    print(f"{new_date}/Donnees/{nom_x[i]}.txt")
    np.savetxt(f"{new_date}/Donnees/{nom_x[i]}.txt", np.flip(X)-x0)
    np.savetxt(f"{new_date}/Donnees/{nom_y[i]}.txt", Y-Y0)

plt.legend(
    loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))
plt.show()

X , Y , label = PROFILS[10]
plt.plot(np.flip(X)-x0,Y - Y0  , label = label )
np.savetxt(f"{new_date}/Donnees/X_coupure2_30ms.txt", np.flip(X)-x0)
np.savetxt(f"{new_date}/Donnees/Y_coupure2_30ms.txt", Y-Y0)


plt.legend(
    loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))
plt.show()
# Out:
# x0 : 697.2292884287644
# x0 : 697.2292884287644
# 2024-04-24/Donnees/X_coupure1_1ms.txt
# 2024-04-24/Donnees/X_coupure1_18ms.txt
# 2024-04-24/Donnees/X_coupure2_1ms.txt
# 2024-04-24/Donnees/X_coupure2_30ms.txt

# %%
if date_donnees == '2024-04-24' :
    fichier_x = "X_coupure1_1ms.txt"
    fichier_y = "Y_coupure1_1ms.txt"
    Donnees = [np.loadtxt(f"{date_donnees}/Donnees/{fichier_x}") , np.loadtxt(f"{date_donnees}/Donnees/{fichier_y}") , 'coupure 1 $\\tau = 1~ms$']
    DONNEES.append(Donnees)
    fichier_x = "X_coupure1_18ms.txt"
    fichier_y = "Y_coupure1_18ms.txt"
    Donnees = [np.loadtxt(f"{date_donnees}/Donnees/{fichier_x}") , np.loadtxt(f"{date_donnees}/Donnees/{fichier_y}") , 'coupure 1 $\\tau = 28~ms$']
    DONNEES.append(Donnees)
    fichier_x = "X_coupure2_1ms.txt"
    fichier_y = "Y_coupure2_1ms.txt"
    Donnees = [np.loadtxt(f"{date_donnees}/Donnees/{fichier_x}") , np.loadtxt(f"{date_donnees}/Donnees/{fichier_y}") , 'coupure 2 $\\tau = 1~ms$']
    DONNEES.append(Donnees)
    fichier_x = "X_coupure2_30ms.txt"
    fichier_y = "Y_coupure2_30ms.txt"
    Donnees = [np.loadtxt(f"{date_donnees}/Donnees/{fichier_x}") , np.loadtxt(f"{date_donnees}/Donnees/{fichier_y}") , 'coupure 2 $30~ms$']
    DONNEES.append(Donnees)

# %%
liste_ind = [4]
nom_x = ["X_insitut","erreur","X_coupure1_1ms","X_coupure1_18ms","X_coupure2_1ms"]
nom_y = ["Y_insitut","erreur","Y_coupure1_1ms","Y_coupure1_18ms","Y_coupure2_1ms"]

Taille = 24.780000000000086 

for i in  liste_ind[-1:]:
    X , Y , label = PROFILS[i]
    plt.plot((np.flip(X)-x0),Y - Y0  , label = label )
    taille((np.flip(X)-x0),Y)

plt.legend(
    loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))
plt.show()
# Out:
# bord_gauche :  32.01071157123556  ; bord_droite : 7.230711571235474
# 19.620711571235518
# Taille bord -24.780000000000086
# le nombre d'atome est  8198.026143972458

# %%
32.01071157123556 - 7.230711571235474
# Out:
# 24.780000000000086

# %%
def polynome(x ,*parameters) :
    y = 0.0 
    for i , p in enumerate(parameters) :
        y += p*np.power(x,i)
    return y 

def polynome2(x ,*parameters) :
    y = 0.0 
    x0 = parameters[0]
    y0 = parameters[1]
    for i , p in enumerate(parameters[2:]) :
        y += p*np.power(x-x0,2*i)
    
    c , b , a = parameters[2:]
    Delta = b**2 - 4*a*c
    racine = [0 , 0 , 0 , 0 ]
    if Delta >= 0 :
        xplus = (-b + np.sqrt(Delta))/(2*a)
        
        xmoins = (-b - np.sqrt(Delta))/(2*a)
        if xmoins >= 0 :
            racine[0] ,racine[1] ,racine[2],  racine[-1] = -np.sqrt(xplus),-np.sqrt(xmoins), np.sqrt(xmoins), np.sqrt(xplus)
        elif xplus>= 0 :
            racine[1] ,racine[2] =  -np.sqrt(xplus), np.sqrt(xplus)
    return np.where((x>racine[1]+x0)*(x<racine[2]+x0), y ,0 )+y0
    return y 

x = np.array([-200 + i for i in range(400)])

plt.plot( x , polynome2(x , *[ 10,10 ,  40,0,-0.000001]))
plt.show()

def cherche (model , x ,y , n , eps ) :#, p0 = np.full ( n , 0.0 ) ):#, bounds=(-1.0e-300, 1.0e-300) ) :
    from scipy.optimize import curve_fit
    yerr = np.full (len(y) , eps ) 
    popt , pcov = curve_fit(model , x , y , sigma = yerr , p0 = np.array([800 ,0 ,  50 , 0 ,- 0.0000001]), 
                            bounds = ([0,-10, 0,-0,-10],[2000,10,  200 , 0.0000001 , 0])
                           )#, bounds=bounds)
    return (popt , pcov )

def chicarre(y,yprim): 
    #print (( y - yprim)**2/yprim)
    #print (filter(lambda x: x != float('-inf'),( y - yprim)**2/yprim))
    
    return sum(filter(lambda x: x != float('inf'),(( y - yprim)**2)/10**2))

def taille(X,Y):
    
    bord_gauche = X[np.argmax(np.gradient(Y))]
    bord_droite = X[np.argmin(np.gradient(Y))]
    
    print((bord_gauche+bord_droite)/2)
    
    #plt.plot(X,Y) 
    #plt.plot(X,np.gradient(Y))
    #plt.vlines(x=bord_droite, ymin=-1, ymax=20, colors='green', ls=':', lw=2)
    #plt.vlines(x=bord_gauche, ymin=-1, ymax=20, colors='green', ls=':', lw=2)
    #plt.xlim([-50 , 50])
    #plt.xlabel('x $(\mu m)$')
    #plt.show()
    
    Taille_exp = bord_droite - bord_gauche 
    print ("Taille bord" , Taille_exp)
    return Taille_exp

best = list(liste_keys)[0]
Taille_exp_b = 10000
chi_b = 1000000
for parametres in liste_keys:
    if len(dict_donnees_renger[parametres])>0 :
        textsave = date_rep +"/X_1D_Scan_"+str(scan)+'_'
        for i in range(len(param_names)):
            textsave += param_names[i] + '-' + str(parametres[i]) + '_'
        textsave += ".txt"
        X = np.genfromtxt(textsave)
        textsave = date_rep +"/Y_1D_Scan_"+str(scan)+'_'
        for i in range(len(param_names)):
            textsave += param_names[i] + '-' + str(parametres[i]) + '_'
        textsave += ".txt"
        Y = np.genfromtxt(textsave)
        xmax = X[np.argmax(Y)]
        if xmax < 1900 and xmax > 800:
            #taille(X,Y)
            plt.plot(X,Y , label = textsave)
            popt , pcov = cherche (polynome2 , X ,Y , 6 , 1.0e-3 )
            #popt = [800 , 50 , 0 ,- 0.0000001]
            print ( 'chi carre = ' ,chicarre(Y,polynome2(X , *popt)) )
            chi = chicarre(Y,polynome2(X , *popt))
            print ( popt[-2] , popt[-1])
            Taille_exp = taille(X,polynome2(X , *popt))
            if chi < chi_b :
                best = parametres
                chi = chi_b
            
            plt.plot(X,polynome2(X , *popt) , '--')
        plt.legend(
    loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))
        plt.show()

parametres = best 
textsave = date_rep +"/X_1D_Scan_"+str(scan)+'_'
for i in range(len(param_names)):
    textsave += param_names[i] + '-' + str(best[i]) + '_'
textsave += ".txt"
X = np.genfromtxt(textsave)
textsave = date_rep +"/Y_1D_Scan_"+str(scan)+'_'
for i in range(len(param_names)):
    textsave += param_names[i] + '-' + str(parametres[i]) + '_'
textsave += ".txt"
Y = np.genfromtxt(textsave)
xmax = X[np.argmax(Y)]
if xmax < 1900 and xmax > 800:
     #taille(X,Y)
    plt.plot(X,Y , label = textsave)
    popt , pcov = cherche (polynome2 , X ,Y , 6 , 1.0e-3 )
    #popt = [800 , 50 , 0 ,- 0.0000001]
    print ( 'chi carre = ' ,chicarre(Y,polynome2(X , *popt)) )
    chi = chicarre(Y,polynome2(X , *popt))
    print ( popt[-2] , popt[-1])
    Taille_exp = taille(X,polynome2(X , *popt))
    plt.plot(X,polynome2(X , *popt) , '--')
    plt.legend(
    loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))
    plt.show()
# Out:
# /tmp/ipykernel_2679997/1054995873.py:22: RuntimeWarning: invalid value encountered in sqrt
#   racine[0] ,racine[1] ,racine[2],  racine[-1] = -np.sqrt(xplus),-np.sqrt(xmoins), np.sqrt(xmoins), np.sqrt(xplus)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[30], line 75
#      73     textsave += param_names[i] + '-' + str(parametres[i]) + '_'
#      74 textsave += ".txt"
# ---> 75 X = np.genfromtxt(textsave)
#      76 textsave = date_rep +"/Y_1D_Scan_"+str(scan)+'_'
#      77 for i in range(len(param_names)):
#
# File ~/miniconda3/envs/py_310/lib/python3.10/site-packages/numpy/lib/npyio.py:1980, in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding, ndmin, like)
#    1978     fname = os_fspath(fname)
#    1979 if isinstance(fname, str):
# -> 1980     fid = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1981     fid_ctx = contextlib.closing(fid)
#    1982 else:
#
# File ~/miniconda3/envs/py_310/lib/python3.10/site-packages/numpy/lib/_datasource.py:193, in open(path, mode, destpath, encoding, newline)
#     156 """
#     157 Open `path` with `mode` and return the file object.
#     158
#    (...)
#     189
#     190 """
#     192 ds = DataSource(destpath)
# --> 193 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File ~/miniconda3/envs/py_310/lib/python3.10/site-packages/numpy/lib/_datasource.py:533, in DataSource.open(self, path, mode, encoding, newline)
#     530     return _file_openers[ext](found, mode=mode,
#     531                               encoding=encoding, newline=newline)
#     532 else:
# --> 533     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: 2024_03_05/X_1D_Scan_89_X1_bis-400.0_DeadtimeDMD_bis-0.5_Width1_bis-1500.0_DeadtimeDMD-0.5_Width1-1500.0_delta--78.0_RFfreqACfinexp-2748.0_Ismalldprquartic-0.865_Ismalldquartic-1.09_BxMOT--3.0_.txt not found.

# %%
X1  = np.genfromtxt("2024_04_24/X_1D_Scan_6_RFfreqACfinexp-2748.0_Ismalldprquartic-0.865_Ismalldquartic-1.095_.txt")
Y1  = np.genfromtxt("2024_04_24/Y_1D_Scan_6_RFfreqACfinexp-2748.0_Ismalldprquartic-0.865_Ismalldquartic-1.095_.txt")

X2  = np.genfromtxt("2024_04_24/X_1D_Scan_34_Width1-900.0_delta--78.0_RFfreqACfinexp-2748.0_Ismalldprquartic-0.865_Ismalldquartic-1.09_.txt")
Y2  = np.genfromtxt("2024_04_24/Y_1D_Scan_34_Width1-900.0_delta--78.0_RFfreqACfinexp-2748.0_Ismalldprquartic-0.865_Ismalldquartic-1.09_.txt")

X3  = np.genfromtxt("2024_04_24/X_1D_Scan_37_Width1-940.0_delta--78.0_RFfreqACfinexp-2748.0_Ismalldprquartic-0.865_Ismalldquartic-1.09_.txt")
Y3  = np.genfromtxt("2024_04_24/Y_1D_Scan_37_Width1-940.0_delta--78.0_RFfreqACfinexp-2748.0_Ismalldprquartic-0.865_Ismalldquartic-1.09_.txt")

X3  = np.genfromtxt("2024_04_24/X_1D_Scan_48_DeadtimeDMD-28.0_Width1-900.0_delta--78.0_RFfreqACfinexp-2748.0_Ismalldprquartic-0.865_Ismalldquartic-1.09_.txt")
Y3  = np.genfromtxt("2024_04_24/Y_1D_Scan_48_DeadtimeDMD-28.0_Width1-900.0_delta--78.0_RFfreqACfinexp-2748.0_Ismalldprquartic-0.865_Ismalldquartic-1.09_.txt")

X4  = np.genfromtxt("2024_04_24/X_1D_Scan_51_DeadtimeDMD-18.0_Width1-900.0_delta--78.0_RFfreqACfinexp-2748.0_Ismalldprquartic-0.865_Ismalldquartic-1.09_.txt")
Y4  = np.genfromtxt("2024_04_24/Y_1D_Scan_51_DeadtimeDMD-18.0_Width1-900.0_delta--78.0_RFfreqACfinexp-2748.0_Ismalldprquartic-0.865_Ismalldquartic-1.09_.txt")

X5  = np.genfromtxt("2024_04_24/X_1D_Scan_56_DeadtimeDMD-18.0_Width1-900.0_delta--78.0_RFfreqACfinexp-2748.0_Ismalldprquartic-0.865_Ismalldquartic-1.09_.txt")
Y5  = np.genfromtxt("2024_04_24/Y_1D_Scan_56_DeadtimeDMD-18.0_Width1-900.0_delta--78.0_RFfreqACfinexp-2748.0_Ismalldprquartic-0.865_Ismalldquartic-1.09_.txt")

X6  = np.genfromtxt("2024_04_24/X_1D_Scan_62_X1_bis-350.0_DeadtimeDMD-18.0_Width1-900.0_delta--78.0_RFfreqACfinexp-2748.0_Ismalldprquartic-0.865_Ismalldquartic-1.09_.txt")
Y6  = np.genfromtxt("2024_04_24/Y_1D_Scan_62_X1_bis-350.0_DeadtimeDMD-18.0_Width1-900.0_delta--78.0_RFfreqACfinexp-2748.0_Ismalldprquartic-0.865_Ismalldquartic-1.09_.txt")

X6  = np.genfromtxt("2024_04_24/X_1D_Scan_62_X1_bis-400.0_DeadtimeDMD-18.0_Width1-900.0_delta--78.0_RFfreqACfinexp-2748.0_Ismalldprquartic-0.865_Ismalldquartic-1.09_.txt")
Y6  = np.genfromtxt("2024_04_24/Y_1D_Scan_62_X1_bis-400.0_DeadtimeDMD-18.0_Width1-900.0_delta--78.0_RFfreqACfinexp-2748.0_Ismalldprquartic-0.865_Ismalldquartic-1.09_.txt")

X7  = np.genfromtxt("2024_04_24/X_1D_Scan_67_X1_bis-400.0_DeadtimeDMD-18.0_Width1-900.0_delta--78.0_RFfreqACfinexp-2748.0_Ismalldprquartic-0.865_Ismalldquartic-1.09_.txt")
Y7  = np.genfromtxt("2024_04_24/Y_1D_Scan_67_X1_bis-400.0_DeadtimeDMD-18.0_Width1-900.0_delta--78.0_RFfreqACfinexp-2748.0_Ismalldprquartic-0.865_Ismalldquartic-1.09_.txt")

x0 = 800
# Tracer les données
#plt.plot(X1-x0, Y1 , linestyle='-' , label = 'Fond')
plt.plot(X1-x0, Y1 , linestyle='-' , label = 'in situe')
plt.plot(X2-x0, Y2, linestyle='-' , label = 'coupune 1 1  ms')
plt.plot(X3-x0, Y3, linestyle='-' , label = 'coupune 1 28  ms')
plt.plot(X4-x0, Y4, linestyle='-' , label = 'coupune 1 18  ms')
plt.plot(X5-x0, Y5, linestyle='-' , label = 'coupune 2 1  ms X1bis = 300 Width1_bis = 60')
plt.plot(X6-x0, Y6, linestyle='-' , label = 'coupune 2 1  ms X1bis = 400 Width1_bis = 60')
plt.plot(X7-x0, Y7, linestyle='-' , label = 'coupune 2 1  ms X1bis = 400 Width1_bis = 50')
# Ajouter des titres et des labels
#plt.title('Tracé des données depuis un fichier .txt')
plt.xlabel('$\mu m$')
plt.ylabel('$\mu m^{-1}$')

#plt.xlim()
#plt.ylim([-1 , 6 ])

# Afficher la figure
plt.legend()
plt.show()

# %%
X1  = np.genfromtxt("2024_04_24/X_1D_Scan_DeadtimeDMD_bis-1.0_DeadtimeDMD-1.0_Width1-0.0_Width1_bis-1500.0_BxMOT--3.0_.txt")
Y1  = np.genfromtxt("2024_04_24/Y_1D_Scan_DeadtimeDMD_bis-1.0_DeadtimeDMD-1.0_Width1-0.0_Width1_bis-1500.0_BxMOT--3.0_.txt")

X2  = np.genfromtxt("2024_04_24/X_1D_Scan_DeadtimeDMD_bis-1.0_DeadtimeDMD-1.0_Width1-1500.0_Width1_bis-1500.0_BxMOT--3.0_.txt")
Y2  = np.genfromtxt("2024_04_24/Y_1D_Scan_DeadtimeDMD_bis-1.0_DeadtimeDMD-1.0_Width1-1500.0_Width1_bis-1500.0_BxMOT--3.0_.txt")


x0 = 800
# Tracer les données
#plt.plot(X1-x0, Y1 , linestyle='-' , label = 'Fond')
plt.plot(X1-x0, Y1 , linestyle='-' , label = 'coupune 1 1  ms')
plt.plot(X2-x0, Y2, linestyle='-' , label = 'coupune 1 18  ms')

# Ajouter des titres et des labels
#plt.title('Tracé des données depuis un fichier .txt')
plt.xlabel('$\mu m$')
plt.ylabel('$\mu m^{-1}$')

#plt.xlim()

# Afficher la figure
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 X1  = np.genfromtxt("2024_04_24/X_1D_Scan_DeadtimeDMD_bis-1.0_DeadtimeDMD-1.0_Width1-0.0_Width1_bis-1500.0_BxMOT--3.0_.txt")
#       2 Y1  = np.genfromtxt("2024_04_24/Y_1D_Scan_DeadtimeDMD_bis-1.0_DeadtimeDMD-1.0_Width1-0.0_Width1_bis-1500.0_BxMOT--3.0_.txt")
#       4 X2  = np.genfromtxt("2024_04_24/X_1D_Scan_DeadtimeDMD_bis-1.0_DeadtimeDMD-1.0_Width1-1500.0_Width1_bis-1500.0_BxMOT--3.0_.txt")
#
# File ~/miniconda3/envs/py_310/lib/python3.10/site-packages/numpy/lib/npyio.py:1980, in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding, ndmin, like)
#    1978     fname = os_fspath(fname)
#    1979 if isinstance(fname, str):
# -> 1980     fid = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1981     fid_ctx = contextlib.closing(fid)
#    1982 else:
#
# File ~/miniconda3/envs/py_310/lib/python3.10/site-packages/numpy/lib/_datasource.py:193, in open(path, mode, destpath, encoding, newline)
#     156 """
#     157 Open `path` with `mode` and return the file object.
#     158
#    (...)
#     189
#     190 """
#     192 ds = DataSource(destpath)
# --> 193 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File ~/miniconda3/envs/py_310/lib/python3.10/site-packages/numpy/lib/_datasource.py:533, in DataSource.open(self, path, mode, encoding, newline)
#     530     return _file_openers[ext](found, mode=mode,
#     531                               encoding=encoding, newline=newline)
#     532 else:
# --> 533     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: 2024_04_24/X_1D_Scan_DeadtimeDMD_bis-1.0_DeadtimeDMD-1.0_Width1-0.0_Width1_bis-1500.0_BxMOT--3.0_.txt not found.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Charger les données depuis le fichier .txt
X1  = np.genfromtxt("2024_04_19/X_1D_Scan_DeadtimeDMD_bis-1.0_DeadtimeDMD-1.0_Width1-0.0_Width1_bis-1500.0_BxMOT--3.0_.txt")
Y1  = np.genfromtxt("2024_04_19/Y_1D_Scan_DeadtimeDMD_bis-1.0_DeadtimeDMD-1.0_Width1-0.0_Width1_bis-1500.0_BxMOT--3.0_.txt")

X2  = np.genfromtxt("2024_04_19/X_1D_Scan_DeadtimeDMD_bis-1.0_DeadtimeDMD-1.0_Width1-1500.0_Width1_bis-1500.0_BxMOT--3.0_.txt")
Y2  = np.genfromtxt("2024_04_19/Y_1D_Scan_DeadtimeDMD_bis-1.0_DeadtimeDMD-1.0_Width1-1500.0_Width1_bis-1500.0_BxMOT--3.0_.txt")

X3  = np.genfromtxt("2024_04_19/X_1D_Scan_DeadtimeDMD_bis-1.0_DeadtimeDMD-1.0_Width1-700.0_Width1_bis-1500.0_BxMOT--3.0_.txt")
Y3  = np.genfromtxt("2024_04_19/Y_1D_Scan_DeadtimeDMD_bis-1.0_DeadtimeDMD-1.0_Width1-700.0_Width1_bis-1500.0_BxMOT--3.0_.txt")

X4  = np.genfromtxt("2024_04_19/X_1D_Scan_DeadtimeDMD_bis-1.0_DeadtimeDMD-18.0_Width1-700.0_Width1_bis-1500.0_BxMOT--3.0_.txt")
Y4  = np.genfromtxt("2024_04_19/Y_1D_Scan_DeadtimeDMD_bis-1.0_DeadtimeDMD-18.0_Width1-700.0_Width1_bis-1500.0_BxMOT--3.0_.txt")

X5  = np.genfromtxt("2024_04_19/X_1D_Scan_DeadtimeDMD_bis-1.0_DeadtimeDMD-18.0_Width1-700.0_Width1_bis-1500.0_BxMOT-0.0_.txt")
Y5  = np.genfromtxt("2024_04_19/Y_1D_Scan_DeadtimeDMD_bis-1.0_DeadtimeDMD-18.0_Width1-700.0_Width1_bis-1500.0_BxMOT-0.0_.txt")

X6  = np.genfromtxt("2024_04_19/X_1D_Scan_DeadtimeDMD_bis-1.0_DeadtimeDMD-18.0_Width1-700.0_Width1_bis-70.0_BxMOT--3.0_.txt")
Y6  = np.genfromtxt("2024_04_19/Y_1D_Scan_DeadtimeDMD_bis-1.0_DeadtimeDMD-18.0_Width1-700.0_Width1_bis-70.0_BxMOT--3.0_.txt")


X7  = np.genfromtxt("2024_04_19/X_1D_Scan_DeadtimeDMD_bis-30.0_DeadtimeDMD-18.0_Width1-700.0_Width1_bis-70.0_BxMOT--3.0_.txt")
Y7  = np.genfromtxt("2024_04_19/Y_1D_Scan_DeadtimeDMD_bis-30.0_DeadtimeDMD-18.0_Width1-700.0_Width1_bis-70.0_BxMOT--3.0_.txt")

X8 = np.genfromtxt("2024-02-29/Donnees/X_coupure2_50ms.txt")
Y8 = np.genfromtxt("2024-02-29/Donnees/Y_coupure2_50ms.txt")

x0 = 800
# Tracer les données
#plt.plot(X1-x0, Y1 , linestyle='-' , label = 'Fond')
plt.plot(X2-x0, Y2-Y1 , linestyle='-' , label = 'In situe')
plt.plot(X3-x0, Y3-Y1, linestyle='-' , label = 'coupune 1 1  ms')
plt.plot(X4-x0, Y4-Y1,  linestyle='-' , label = 'coupure 1 18 ms')
#plt.plot(X5-x0, Y5,  linestyle='-' , label = 'FOND Bx ')
plt.plot(X6-x0, Y6-Y1,  linestyle='-' , label = 'coupure 2 1  ms')
plt.plot(X7-x0, Y7-Y1,  linestyle='-' , label = 'coupure 2 30 ms')

# Ajouter des titres et des labels
#plt.title('Tracé des données depuis un fichier .txt')
plt.xlabel('$\mu m$')
plt.ylabel('$\mu m^{-1}$')

#plt.xlim()

# Afficher la figure
plt.legend()
plt.show()

# Charger les données depuis le fichier .txt
X1f  = np.genfromtxt("2024-02-29/Donnees/X_coupure1_1ms.txt")
Y1f  = np.genfromtxt("2024-02-29/Donnees/Y_coupure1_1ms.txt")

X2f  = np.genfromtxt("2024-02-29/Donnees/X_coupure1_28ms.txt")
Y2f  = np.genfromtxt("2024-02-29/Donnees/Y_coupure1_28ms.txt")

X3f  = np.genfromtxt("2024-02-29/Donnees/X_coupure2_1ms.txt")
Y3f  = np.genfromtxt("2024-02-29/Donnees/Y_coupure2_1ms.txt")

X4f  = np.genfromtxt("2024-02-29/Donnees/X_coupure2_50ms.txt")
Y4f  = np.genfromtxt("2024-02-29/Donnees/Y_coupure2_50ms.txt")

x0f = 0 
plt.plot(X1f-x0f, Y1f , linestyle='-' , label = 'coupure 1 1ms')
plt.plot(X2f-x0f, Y2f , linestyle='-' , label = 'coupure 1 28ms')
plt.plot(X3f-x0f, Y3f , linestyle='-' , label = 'coupure 2 1ms')
plt.plot(X4f-x0f, Y4f , linestyle='-' , label = 'coupure 2 50ms')
plt.title("29 fev 2024")
plt.xlabel('$\mu m$')
plt.ylabel('$\mu m^{-1}$')
plt.legend()
plt.show()


plt.plot((X7-x0)/39, Y7-Y1,  linestyle='-' , label = 'coupure 2 30 ms')
plt.plot((X8)/54, Y8,  linestyle='-' , label = 'coupure 2 50 ms fev 29')
plt.xlabel('$x/\ell$')
plt.ylabel('$\mu m^{-1}$')
plt.legend()
plt.show()

plt.plot(X1-x0, Y1 , linestyle='-' , label = 'Fond')
plt.plot(X5-x0, Y5,  linestyle='-' , label = 'FOND Bx ')
plt.xlabel('$\mu m$')
plt.ylabel('$\mu m^{-1}$')
plt.legend()
plt.show()

def taille(X,Y):
    
    bord_gauche = X[np.argmax(np.gradient(Y))]-x0
    bord_droite = X[np.argmin(np.gradient(Y))]-x0
    
    print((bord_gauche+bord_droite)/2)
    
    plt.plot(X-x0,Y) 
    plt.plot(X-x0,np.gradient(Y))
    plt.vlines(x=bord_droite, ymin=-1, ymax=20, colors='green', ls=':', lw=2)
    plt.vlines(x=bord_gauche, ymin=-1, ymax=20, colors='green', ls=':', lw=2)
    #plt.xlim([-50 , 50])
    plt.xlabel('x $(\mu m)$')
    plt.show()
    
    Taille_exp = bord_droite - bord_gauche 
    print ("Taille bord" , Taille_exp)
    
taille(X6,Y6)

taille(X3f,Y3f)

print (30/33 , 50/55)

print ( 400*18/60)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[32], line 27
#      24 X7  = np.genfromtxt("2024_04_19/X_1D_Scan_DeadtimeDMD_bis-30.0_DeadtimeDMD-18.0_Width1-700.0_Width1_bis-70.0_BxMOT--3.0_.txt")
#      25 Y7  = np.genfromtxt("2024_04_19/Y_1D_Scan_DeadtimeDMD_bis-30.0_DeadtimeDMD-18.0_Width1-700.0_Width1_bis-70.0_BxMOT--3.0_.txt")
# ---> 27 X8 = np.genfromtxt("2024-02-29/Donnees/X_coupure2_50ms.txt")
#      28 Y8 = np.genfromtxt("2024-02-29/Donnees/Y_coupure2_50ms.txt")
#      30 x0 = 800
#
# File ~/miniconda3/envs/py_310/lib/python3.10/site-packages/numpy/lib/npyio.py:1980, in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding, ndmin, like)
#    1978     fname = os_fspath(fname)
#    1979 if isinstance(fname, str):
# -> 1980     fid = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1981     fid_ctx = contextlib.closing(fid)
#    1982 else:
#
# File ~/miniconda3/envs/py_310/lib/python3.10/site-packages/numpy/lib/_datasource.py:193, in open(path, mode, destpath, encoding, newline)
#     156 """
#     157 Open `path` with `mode` and return the file object.
#     158
#    (...)
#     189
#     190 """
#     192 ds = DataSource(destpath)
# --> 193 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File ~/miniconda3/envs/py_310/lib/python3.10/site-packages/numpy/lib/_datasource.py:533, in DataSource.open(self, path, mode, encoding, newline)
#     530     return _file_openers[ext](found, mode=mode,
#     531                               encoding=encoding, newline=newline)
#     532 else:
# --> 533     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: 2024-02-29/Donnees/X_coupure2_50ms.txt not found.
